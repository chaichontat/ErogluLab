# %%
import os, math
import numpy as np
import pandas as pd


def check_prereqs():
    if layers:
        if 'X' not in df.columns:
            raise Exception('Centroid box not checked in ImageJ')

def segmentbyXY(axis, thr):
    column = df[axis]
    maximum = column.max()
    numlayer = math.floor(maximum / thr) + 1 # To get last partial layer
    
    thrarray = [i*thr for i in range(numlayer+1)] # Values are minimum X or Y
    result = np.zeros(numlayer, dtype=np.int64)
    for i in range(numlayer):
        result[i] = column[(column > thrarray[i]) & (column < thrarray[i+1])].values.size
    return result
    

directory = "/home/eroglulab/Desktop/Combi/Olg2Sox9"

layers = True
first = True
f = open(directory + "/" + "Output.txt", 'w')

f.write("Name\tTotal\tLayer1\tLayer2\n")

for file in os.listdir(directory):
    if file.endswith(".csv") and file.startswith("Cut"):
        df = pd.read_csv(directory + "/" + file)
        df.drop(df.columns[0], axis='columns', inplace=True) # Remove count column
        
        if first:
            bigdf = pd.DataFrame
            check_prereqs()

        f.write(file + "\t")
        f.write(str(df.count()[0]) + "\t")
        output = segmentbyXY('Y', 150)
        
        for i in range(len(output)):
            f.write("{:d}".format(output[i]) + "\t")
        f.write("\n")        
f.close()

# %%
import os, math
import numpy as np
import pandas as pd

directory = "/media/eroglulab/Chaichontat/New folder/Combi/Sox9/Cut"
file ="Seg_Sox9_1529-31830-13092.tif.csv"

df = pd.read_csv(directory + "/" + file)
df.drop(df.columns[0], axis='columns', inplace=True) # Remove count column

# %%
bigdf = pd.DataFrame(columns=['Name', 'Counts'])

# %%
total = df.size # Total count

# %%
colset = ['Name', 'Counts']

# %%
df.count()[0]
# Out:
# 180

# %%
bigdf.append(pd.DataFrame([file, total], columns=colset), ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/miniconda3/envs/tf_gpu/lib/python3.6/site-packages/pandas/core/internals.py in create_block_manager_from_blocks(blocks, axes)
#    4856                 blocks = [make_block(values=blocks[0],
# -> 4857                                      placement=slice(0, len(axes[0])))]
#    4858
#
# ~/miniconda3/envs/tf_gpu/lib/python3.6/site-packages/pandas/core/internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3204
# -> 3205     return klass(values, ndim=ndim, placement=placement)
#    3206
#
# ~/miniconda3/envs/tf_gpu/lib/python3.6/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim)
#    2302         super(ObjectBlock, self).__init__(values, ndim=ndim,
# -> 2303                                           placement=placement)
#    2304
#
# ~/miniconda3/envs/tf_gpu/lib/python3.6/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim)
#     124                 'Wrong number of items passed {val}, placement implies '
# --> 125                 '{mgr}'.format(val=len(self.values), mgr=len(self.mgr_locs)))
#     126
#
# ValueError: Wrong number of items passed 1, placement implies 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-969ee9583511> in <module>
# ----> 1 bigdf.append(pd.DataFrame([file, total], columns=colset), ignore_index=True)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     401                 else:
#     402                     mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 403                                              copy=copy)
#     404             else:
#     405                 mgr = self._init_dict({}, index, columns, dtype=dtype)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.6/site-packages/pandas/core/frame.py in _init_ndarray(self, values, index, columns, dtype, copy)
#     534             values = maybe_infer_to_datetimelike(values)
#     535
# --> 536         return create_block_manager_from_blocks([values], [columns, index])
#     537
#     538     @property
#
# ~/miniconda3/envs/tf_gpu/lib/python3.6/site-packages/pandas/core/internals.py in create_block_manager_from_blocks(blocks, axes)
#    4864         blocks = [getattr(b, 'values', b) for b in blocks]
#    4865         tot_items = sum(b.shape[0] for b in blocks)
# -> 4866         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    4867
#    4868
#
# ~/miniconda3/envs/tf_gpu/lib/python3.6/site-packages/pandas/core/internals.py in construction_error(tot_items, block_shape, axes, e)
#    4841         raise ValueError("Empty data passed with indices specified.")
#    4842     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 4843         passed, implied))
#    4844
#    4845
#
# ValueError: Shape of passed values is (1, 2), indices imply (2, 2)

# %%
bigdf[bigdf.size] = pd.Series([file,total])

# %%
bigdf
# Out:
#                                                 Name Counts  \
# 0  Olg2_Stitched_DEP30.9_P8FWT_488Olg2_594NeuN_64...    339
#
#                                                    2  \
# 0  Olg2_Stitched_DEP30.9_P8FWT_488Olg2_594NeuN_64...
#
#                                                    3
# 0  Olg2_Stitched_DEP30.9_P8FWT_488Olg2_594NeuN_64...

# %%
bigdf.to_csv(index=False)
# Out:
# 'Name,Counts\nOlg2_Stitched_DEP30.9_P8FWT_488Olg2_594NeuN_647Sox9_ACC23_P1_A01_G001.tif.csv,339\n'

# %%
df
# Out:
#      Area         X        Y
# 0      87   670.546    4.397
# 1      85  1005.829   20.794
# 2     120   603.642   22.308
# 3      98   788.673   27.959
# 4     112   714.321   32.804
# 5      97   828.067   40.407
# 6     110   901.918   40.264
# 7     142   758.789   50.620
# 8     136   920.125   48.728
# 9      99   607.227   53.126
# 10     64   677.453   58.422
# 11    118   927.415   66.415
# 12    130   975.623   70.108
# 13    121   789.550   95.847
# 14    113   486.748  100.969
# 15     55   523.355  103.791
# 16     72   847.583  108.458
# 17     87   865.328  112.190
# 18    135   567.841  118.589
# 19     58   451.569  122.190
# 20    107   687.995  123.921
# 21    103   786.257  162.257
# 22    171   811.500  173.482
# 23    105   754.281  177.852
# 24    101   765.262  195.252
# 25    133   858.665  197.944
# 26    118   612.246  211.127
# 27    112   686.464  214.250
# 28    117   570.372  216.132
# 29    120   413.808  219.158
# ..    ...       ...      ...
# 83    108   525.222  632.019
# 84    111   405.293  635.527
# 85    144   164.521  640.924
# 86    118   593.686  638.085
# 87    137   246.894  642.252
# 88    118   396.636  649.102
# 89     86   344.860  659.651
# 90     97   229.418  666.057
# 91    158   460.348  667.380
# 92    118   601.339  670.814
# 93    113   281.544  672.845
# 94    105   480.767  683.976
# 95    107   387.780  692.734
# 96    108   478.102  716.991
# 97    134   338.261  716.358
# 98     96   121.729  716.490
# 99     89   466.983  718.904
# 100    83   114.054  724.681
# 101    85   306.982  727.324
# 102    52   100.308  734.192
# 103   119   367.399  737.592
# 104   159   393.009  752.381
# 105   110   270.664  777.664
# 106   160   226.488  779.281
# 107   157   357.309  800.589
# 108   157   402.373  823.124
# 109   144   108.660  830.861
# 110   111   321.257  833.752
# 111    75   334.873  837.820
# 112   130   421.946  843.569
#
# [113 rows x 3 columns]
